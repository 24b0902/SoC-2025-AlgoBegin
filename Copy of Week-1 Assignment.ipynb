# %% [markdown]
# # **AlgoBegin: First Steps into Competitive Programming**

# %% [markdown]
# Week-1 Assignment

# %% [markdown]
# **1.**Write a program that takes two integers as input and prints their sum and product on two separate lines.
#
# **Input Format:**
#
# Two integers separated by space.
#
# **Output Format:**
#
# First line: Sum
#
# Second line: Product

# %%
int1=input("Enter first number: ")
int2=input("Enter second number:")
print("Sum:" , (int(int1)+int(int2)))
print("Product:" ,(int(int1)*int(int2)))
# Out:
# Enter first number: 2
# Enter second number:3
# Sum: 5
# Product: 6

# %% [markdown]
# **2.**Given a string, print the number of vowels in it.
#
# **Input Format:**
#
# A single string (lowercase only).
#
# **Output Format:**
#
# A single integer — count of vowels.

# %%
input_string=input("Enter a string in lowercase only:")
count=0
for char in input_string:
  if char=="a" or char=="e" or char=="i" or char=="o" or char=="u":
    count+=1
print(count)
# Out:
# Enter a string in lowercase only:akhve
# 2

# %% [markdown]
# **3.**Given a lowercase character c and a non-negative integer k, output the character that is k positions after c in the alphabet. Wrap around from 'z' to 'a' if needed.
#
# **Input Format:**
#
# One character and one integer separated by space
#
# **Output Format:**
#
# One character (the shifted result)

# %%
ip=input("Enter one character and one integer seperated by space:").split()
character=ip[0]
num=int(ip[1])
print(chr((ord(character)+num-ord('a'))%26+ord('a')))
# Out:
# Enter one character and one integer seperated by space:c -2
# a

# %% [markdown]
# **4.**Keep taking integer input until you get a negative number. Then print the total number of digits (0–9) you encountered in the input before the negative number.
#
# **Input Format:**
#
# One integer per line until a negative number is entered.
#
# **Output Format:**
#
# A single integer (total count of digits seen).

# %%
count=0
ip=input("Enter one integer:")
ipn=int(ip)
if ipn>=10:
  for letter in ip:
   count+=1
while ipn>=0:
  ip=(input("Enter one integer:"))
  ipn=int(ip)
  if ipn<0:
    break
  for letter in ip:
    count+=1

print(count)
# Out:
# Enter one integer:-1
# 0

# %% [markdown]
# **5.**You're given n integers. Print the sum of all numbers that are divisible by 3 or 5 but not both.
#
# **Input Format:**
#
# First line: n
#
# Second line: n integers separated by space
#
# **Output Format:**
#
# Single integer (sum of required numbers)

# %%
nums=int(input("Enter the number of integers:"))
ip=input("Enter the integers seperated by space:").split()
sum=0
for num in ip:
  if (int(num)%3==0 or int(num)%5==0) and (not(int(num)%3==0 and int(num)%5==0)):
    sum+=int(num)
print(sum)
# Out:
# Enter the number of integers:5
# Enter the integers seperated by space:1 4 3 5 15 40
# 48

# %% [markdown]
# **6.**Given a positive integer n, keep summing its digits until you're left with a single-digit number. Return that number.
#
# **Input Format:**
#
# A single integer
#
# **Output Format:**
#
# The single-digit result

# %%
ip=input("Enter a positive integer:")
def sums(n):
  sum=0
  for a in n:
    sum+=int(a)
  if(0<sum<10):
    return sum
  else:
    return sums(str(sum))
print(sums(ip))
# Out:
# Enter a positive integer:2844
# 9
